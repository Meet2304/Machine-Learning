# %% [markdown]
# # Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('House_Price.csv')
data.describe()
# Out:
#         bedrooms  bathrooms  sqft_living       sqft_lot     floors  \
# count  94.000000  94.000000    94.000000      94.000000  94.000000
# mean    3.468085   2.191489  2120.659574   19114.680851   1.553191
# std     0.851338   0.722549   958.299362   35392.708815   0.560664
# min     2.000000   1.000000   900.000000     941.000000   1.000000
# 25%     3.000000   2.000000  1422.500000    6165.250000   1.000000
# 50%     3.000000   2.000000  1865.000000    8392.500000   2.000000
# 75%     4.000000   2.000000  2515.000000   11971.250000   2.000000
# max     6.000000   4.000000  5180.000000  217800.000000   3.000000
#
#               price
# count  9.400000e+01
# mean   5.780266e+05
# std    3.734640e+05
# min    1.379000e+05
# 25%    3.550000e+05
# 50%    5.089750e+05
# 75%    6.697500e+05
# max    2.540000e+06

# %%
data.isna().sum()
# Out:
# bedrooms       0
# bathrooms      0
# sqft_living    0
# sqft_lot       0
# floors         0
# price          0
# dtype: int64

# %%
# Create a pairplot of the dataset
sns.pairplot(data, hue = 'price')
# Show the plot
plt.show()
